# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
path = os.getcwd()

# %%
device_data = pd.read_csv(path+"\\Data\\device_failure.csv",encoding='ISO-8859-1')

# %%
device_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000197D6A7DB20>,
# ...
#       dtype=object)
